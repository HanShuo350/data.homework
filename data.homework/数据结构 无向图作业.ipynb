# %% [markdown]
# 我来分析这个无向图，写出其**邻接矩阵**和**邻接表**表示。
#
# ## 第一步：确定图中的边
#
# 根据图像，6个顶点（A, B, C, D, E, F）之间的边如下：
#
# | 边 | 连接的顶点 |
# |---|---|
# | 1 | A — B |
# | 2 | A — C |
# | 3 | A — F |
# | 4 | B — C |
# | 5 | B — E |
# | 6 | C — D |
# | 7 | D — E |
# | 8 | E — F |
#
# ---
#
# ## 第二步：邻接矩阵
#
# 用 1 表示有边相连，0 表示无边（对角线为0）：
#
# |  | **A** | **B** | **C** | **D** | **E** | **F** |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | **A** | 0 | 1 | 1 | 0 | 0 | 1 |
# | **B** | 1 | 0 | 1 | 0 | 1 | 0 |
# | **C** | 1 | 1 | 0 | 1 | 0 | 0 |
# | **D** | 0 | 0 | 1 | 0 | 1 | 0 |
# | **E** | 0 | 1 | 0 | 1 | 0 | 1 |
# | **F** | 1 | 0 | 0 | 0 | 1 | 0 |
#
# > 邻接矩阵是对称的（无向图的性质）。
#
# ---
#
# ## 第三步：邻接表
#
# 每个顶点列出其所有邻接顶点：
#
# | 顶点 | 邻接顶点 |
# |:---|:---|
# | **A** | → B → C → F |
# | **B** | → A → C → E |
# | **C** | → A → B → D |
# | **D** | → C → E |
# | **E** | → B → D → F |
# | **F** | → A → E |
#
# ---
#
# ## 验证
#
# - 总边数：8条（邻接矩阵中 1 的个数为 16，16÷2 = 8 ✓）
# - 每个顶点的度数：
#   - deg(A) = 3, deg(B) = 3, deg(C) = 3
#   - deg(D) = 2, deg(E) = 3, deg(F) = 2
# - 度数之和 = 3+3+3+2+3+2 = 16 = 2×8 ✓（握手定理）
